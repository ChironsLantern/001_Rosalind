# %%
dna = "ACTG"
print(len(dna))  # Output: 4x = "omg_I_cant_believe_the_OSU_kicker_just_missed_that_field_goal"

x = "omg_I_cant_believe_the_OSU_kicker_just_missed_that_field_goal"
print(x)

print(len(dna))
